# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('Dataset2_UsedCarData.xlsx')

df.head()
# Out:
#                  vin back_legroom        body_type      city  \
# 0  ZACNJABB5KPJ92081      35.1 in  SUV / Crossover   Bayamon
# 1  SALCJ2FX1LH858117      38.1 in  SUV / Crossover  San Juan
# 2  JF1VA2M67G9829723      35.4 in            Sedan  Guaynabo
# 3  SALRR2RV0L2433391      37.6 in  SUV / Crossover  San Juan
# 4  SALCJ2FXXLH862327      38.1 in  SUV / Crossover  San Juan
#
#    city_fuel_economy  combine_fuel_economy  daysonmarket  dealer_zip  \
# 0                NaN                   NaN           522         960
# 1                NaN                   NaN           207         922
# 2               17.0                   NaN          1233         969
# 3                NaN                   NaN           196         922
# 4                NaN                   NaN           137         922
#
#   engine_cylinders  engine_displacement engine_type exterior_color  fleet  \
# 0               I4               1300.0          I4   Solar Yellow    NaN
# ...

# %%
backup = df.copy

# %%
df['back_legroom'] = df['back_legroom'].str.replace(' in', '')

# %%
df.head()
# Out:
#                  vin back_legroom        body_type      city  \
# 0  ZACNJABB5KPJ92081         35.1  SUV / Crossover   Bayamon
# 1  SALCJ2FX1LH858117         38.1  SUV / Crossover  San Juan
# 2  JF1VA2M67G9829723         35.4            Sedan  Guaynabo
# 3  SALRR2RV0L2433391         37.6  SUV / Crossover  San Juan
# 4  SALCJ2FXXLH862327         38.1  SUV / Crossover  San Juan
#
#    city_fuel_economy  combine_fuel_economy  daysonmarket  dealer_zip  \
# 0                NaN                   NaN           522         960
# 1                NaN                   NaN           207         922
# 2               17.0                   NaN          1233         969
# 3                NaN                   NaN           196         922
# 4                NaN                   NaN           137         922
#
#   engine_cylinders  engine_displacement engine_type exterior_color  fleet  \
# 0               I4               1300.0          I4   Solar Yellow    NaN
# ...

# %%
df['body_type'] = df['body_type'].replace('SUV / Crossover', 'SUV')
df = df.dropna(subset=['body_type'])
df['body_type'].unique()
# Out:
# array(['SUV', 'Sedan', 'Coupe', 'Hatchback', 'Pickup Truck', 'Wagon',
#        'Minivan', 'Van', 'Convertible'], dtype=object)

# %%
df = df.drop('combine_fuel_economy', axis = 1)

mean_city_fuel_economy = df['city_fuel_economy'].mean()
df['city_fuel_economy'].fillna(mean_city_fuel_economy, inplace=True)

df = df.drop('engine_cylinders', axis = 1)

df['engine_type'] = df['engine_type'].str.replace('V6 Diesel', 'V6D')
df['engine_type'] = df['engine_type'].str.replace('V8 Biodiesel', 'V8B')
df['engine_type'] = df['engine_type'].str.replace('V8 Flex Fuel Vehicle', 'V8FFV')
df['engine_type'] = df['engine_type'].str.replace('V6 Flex Fuel Vehicle', 'V6FFV')
df['engine_type'] = df['engine_type'].str.replace('I4 Hybrid', 'I4H')
df['engine_type'] = df['engine_type'].str.replace('V6 Hybrid', 'V6H')
df['engine_type'] = df['engine_type'].str.replace('I4 Flex Fuel Vehicle', 'I4FFV')
df['engine_type'] = df['engine_type'].str.replace('I4 Diesel', 'I4D')

mode_engine_type = df['engine_type'].mode()[0]
df['engine_type'] = df['engine_type'].fillna(mode_engine_type)

threshold = 25
counts = df['exterior_color'].value_counts()
df['exterior_color'] = np.where(df['exterior_color'].isin(counts.index[counts < threshold]), 'Other', df['exterior_color'])
mode_exterior_color = df['exterior_color'].mode()[0]
df['exterior_color'] = df['exterior_color'].fillna(mode_exterior_color)


mode_fleet = df['fleet'].mode()[0]
df['fleet'].fillna(mode_fleet, inplace=True)
df['fleet'] = df['fleet'].map({1.0: 1, 0.0: 0})

df = df.drop('frame_damaged', axis=1)

df['franchise_dealer'] = df['franchise_dealer'].map({True: 1, False: 0})


df['front_legroom'] = df['front_legroom'].str.replace(' in', '')
df['fuel_tank_volume'] = df['fuel_tank_volume'].str.replace(' gal', '')


mode_franchise_make = df['franchise_make'].mode()[0]
df['franchise_make'] = df['franchise_make'].fillna(mode_franchise_make)

mode_has_accidents = df['has_accidents'].mode()[0]
df['has_accidents'].fillna(mode_has_accidents, inplace=True)
df['has_accidents'] = df['has_accidents'].map({1.0: 1, 0.0: 0 })

df['height'] = df['height'].str.replace(' in', '')

mean_highway_fuel_economy = df['highway_fuel_economy'].mean()
df['highway_fuel_economy'].fillna(mean_highway_fuel_economy, inplace=True)

mean_horsepower = df['horsepower'].mean()
df['horsepower'].fillna(mean_horsepower, inplace=True)

threshold = 25
counts = df['interior_color'].value_counts()
df['interior_color'] = np.where(df['interior_color'].isin(counts.index[counts < threshold]), 'Other', df['interior_color'])
mode_interior_color = df['interior_color'].mode()[0]
df['interior_color'] = df['interior_color'].fillna(mode_interior_color)

mode_isCab = df['isCab'].mode()[0]
df['isCab'].fillna(mode_isCab, inplace=True)
df['isCab'] = df['isCab'].map({1.0: 1, 0.0: 0 })

df = df.drop('is_certified', axis = 1)
df = df.drop('is_cpo', axis = 1)

df['is_new'] = df['is_new'].map({True: 1, False: 0})

df = df.drop('is_oemcpo', axis = 1)

df['length'] = df['length'].str.replace(' in', '')

df['listing_color'] = df['listing_color'].replace('UNKNOWN', pd.NA)
mode_listing_color = df['listing_color'].mode()[0]
df['listing_color'] = df['listing_color'].fillna(mode_listing_color)

df['maximum_seating'] = df['maximum_seating'].str.replace(' seats', '')

df['mileage'].replace(0, df['mileage'].mean(), inplace=True)
df['mileage'].fillna(df['mileage'].mean(), inplace=True)

mode_salvage = df['salvage'].mode()[0]
df['salvage'].fillna(mode_salvage)
df['salvage'] = df['salvage'].map({1.0: 1, 0.0: 0})

mean_seller_rating = df['seller_rating'].mean()
df['seller_rating'].fillna(mean_seller_rating, inplace=True)


mode_transmission = df['transmission'].mode()[0]
df['transmission'] = df['transmission'].fillna(mode_transmission)


print(df['transmission_display'].unique())
mode_transmission_display = df['transmission_display'].mode()[0]
df['transmission_display'] = df['transmission_display'].fillna(mode_transmission_display)

df = df.drop('vehicle_damage_category', axis = 1)

mode_wheel_system = df['wheel_system'].mode()[0]
df['wheel_system'] = df['wheel_system'].fillna(mode_wheel_system)

df = df.drop('wheel_system_display', axis = 1)

df['wheelbase'] = df['wheelbase'].str.replace(' in', '')
df['width'] = df['width'].str.replace(' in', '')
# Out:
# ['9-Speed Automatic Overdrive' '6-Speed Manual'
#  '8-Speed Automatic Overdrive' '6-Speed Automatic Overdrive'
#  '6-Speed Automatic' '8-Speed Automatic' '9-Speed Automatic'
#  'Continuously Variable Transmission' '5-Speed Automatic'
#  '7-Speed Automatic' 'Automatic' nan 'Manual' '6-Speed Dual Clutch'
#  '1-Speed Automatic' '4-Speed Automatic' '5-Speed Manual'
#  '4-Speed Automatic Overdrive' '5-Speed Automatic Overdrive'
#  '3-Speed Automatic']

# %%
df.head()
# Out:
#                  vin back_legroom body_type      city  city_fuel_economy  \
# 0  ZACNJABB5KPJ92081         35.1       SUV   Bayamon          20.699594
# 1  SALCJ2FX1LH858117         38.1       SUV  San Juan          20.699594
# 2  JF1VA2M67G9829723         35.4     Sedan  Guaynabo          17.000000
# 3  SALRR2RV0L2433391         37.6       SUV  San Juan          20.699594
# 4  SALCJ2FXXLH862327         38.1       SUV  San Juan          20.699594
#
#    daysonmarket  dealer_zip  engine_displacement engine_type exterior_color  \
# 0           522         960               1300.0          I4          Other
# 1           207         922               2000.0          I4          Other
# 2          1233         969               2500.0          H4          Other
# 3           196         922               3000.0          V6          Other
# 4           137         922               2000.0          I4          Other
#
# ...

# %%
df.shape
# Out:
# (996, 53)

# %%
df.isnull().sum()
# Out:
# vin                       0
# back_legroom             19
# body_type                 0
# city                      0
# city_fuel_economy         0
# daysonmarket              0
# dealer_zip                0
# engine_displacement      20
# engine_type               0
# exterior_color            0
# fleet                     0
# franchise_dealer          0
# franchise_make            0
# front_legroom            19
# fuel_tank_volume         19
# fuel_type                14
# has_accidents             0
# height                   19
# highway_fuel_economy      0
# horsepower                0
# interior_color            0
# isCab                     0
# is_new                    0
# latitude                  0
# length                   19
# listed_date               0
# listing_color             0
# listing_id                0
# longitude                 0
# main_picture_url        121
# major_options            49
# make_name                 0
# maximum_seating          19
# ...

# %%
df['back_legroom'] = pd.to_numeric(df['back_legroom'], errors='coerce')
df['back_legroom'] = df['back_legroom'].replace(pd.NA, df['back_legroom'].mean())
df['back_legroom'] = df['back_legroom'].fillna(df['back_legroom'].mean())

df['engine_displacement'] = df['engine_displacement'].fillna(df['engine_displacement'].mean())

df['front_legroom'] = pd.to_numeric(df['front_legroom'], errors='coerce')
df['front_legroom'] = df['front_legroom'].replace(pd.NA, df['front_legroom'].mean())
df['front_legroom'] = df['front_legroom'].fillna(df['front_legroom'].mean())

df['fuel_tank_volume'] = pd.to_numeric(df['fuel_tank_volume'], errors='coerce')
df['fuel_tank_volume'] = df['fuel_tank_volume'].fillna(df['fuel_tank_volume'].mean())

mode_fuel_type = df['fuel_type'].mode()[0]
df['fuel_type'] = df['fuel_type'].fillna(mode_fuel_type)

df['height'] = pd.to_numeric(df['height'], errors='coerce')
df['height'] = df['height'].fillna(df['height'].mean())

df['length'] = pd.to_numeric(df['length'], errors='coerce')
df['length'] = df['length'].fillna(df['length'].mean())

df['maximum_seating'] = pd.to_numeric(df['maximum_seating'], errors='coerce')
df['maximum_seating'] = df['maximum_seating'].fillna(df['maximum_seating'].mean())

df['wheelbase'] = pd.to_numeric(df['wheelbase'], errors='coerce')
df['wheelbase'] = df['wheelbase'].fillna(df['wheelbase'].mean())

df['width'] = pd.to_numeric(df['width'], errors='coerce')
df['width'] = df['width'].fillna(df['width'].mean())

def extract_torque(torque_string):
    if pd.isna(torque_string):
        return None
    return int(torque_string.split()[0])

df['torque'] = df['torque'].apply(extract_torque)

df['torque'] = df['torque'].fillna(df['torque'].mean())

unnecessary_columns = ['main_picture_url', 'major_options', 'owner_count', 'power', 'theft_title', 'trimId', 'trim_name', 'listed_date']

for i in unnecessary_columns:
    df = df.drop(i, axis=1)

# %%
print(df.isnull().sum())
print(df.shape)
# Out:
# vin                       0
# back_legroom              0
# body_type                 0
# city                      0
# city_fuel_economy         0
# daysonmarket              0
# dealer_zip                0
# engine_displacement       0
# engine_type               0
# exterior_color            0
# fleet                     0
# franchise_dealer          0
# franchise_make            0
# front_legroom             0
# fuel_tank_volume          0
# fuel_type                 0
# has_accidents             0
# height                    0
# highway_fuel_economy      0
# horsepower                0
# interior_color            0
# isCab                     0
# is_new                    0
# latitude                  0
# length                    0
# listing_color             0
# listing_id                0
# longitude                 0
# make_name                 0
# maximum_seating           0
# mileage                   0
# model_name                0
# price                     0
# ...

# %%
df.shape
# Out:
# (996, 45)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

corr_mat = df.select_dtypes(include=['float64', 'int64']).corr()

sns.heatmap(corr_mat, annot=True, cmap="coolwarm", fmt=".2f")

plt.show()

# %%
df = df.drop(columns=['listing_id', 'city_fuel_economy', 'front_legroom', 'longitude', 'length', 'daysonmarket'], axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

corr_mat = df.select_dtypes(include=['float64', 'int64']).corr()

sns.heatmap(corr_mat, annot=True, cmap="coolwarm", fmt=".2f")

plt.show()

# %%
df = df.drop(columns=['isCab','engine_displacement','dealer_zip','torque', 'franchise_dealer', 'year','wheelbase'], axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

corr_mat = df.select_dtypes(include=['float64', 'int64']).corr()

sns.heatmap(corr_mat, annot=True, cmap="coolwarm", fmt=".2f")

plt.show()

# %%
df = df.drop(columns=['width','height'], axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

corr_mat = df.select_dtypes(include=['float64', 'int64']).corr()

sns.heatmap(corr_mat, annot=True, cmap="coolwarm", fmt=".2f")

plt.show()

# %%
df = df.drop('latitude', axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

corr_mat = df.select_dtypes(include=['float64', 'int64']).corr()

sns.heatmap(corr_mat, annot=True, cmap="coolwarm", fmt=".2f")

plt.show()

# %%
df.select_dtypes(include=['object','float64', 'int64']).columns
# Out:
# Index(['vin', 'back_legroom', 'body_type', 'city', 'engine_type',
#        'exterior_color', 'fleet', 'franchise_make', 'fuel_tank_volume',
#        'fuel_type', 'has_accidents', 'highway_fuel_economy', 'horsepower',
#        'interior_color', 'is_new', 'listing_color', 'make_name',
#        'maximum_seating', 'mileage', 'model_name', 'price', 'salvage',
#        'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'transmission',
#        'transmission_display', 'wheel_system'],
#       dtype='object')

# %%
df['fleet'] = df['fleet'].astype('object')
df['has_accidents'] = df['has_accidents'].astype('object')
df['is_new'] = df['is_new'].astype('object')

df = df.drop(columns=['model_name','salvage','sp_id','sp_name','transmission_display','vin','city',], axis=1)

df['fleet'] = df['fleet'].map({0:False, 1:True})
df['has_accidents'] = df['has_accidents'].map({0:False, 1:True})
df['is_new'] = df['is_new'].map({0:False, 1:True})

# %%
df.dtypes
# Out:
# back_legroom            float64
# body_type                object
# engine_type              object
# exterior_color           object
# fleet                      bool
# franchise_make           object
# fuel_tank_volume        float64
# fuel_type                object
# has_accidents              bool
# highway_fuel_economy    float64
# horsepower              float64
# interior_color           object
# is_new                     bool
# listing_color            object
# make_name                object
# maximum_seating         float64
# mileage                 float64
# price                     int64
# savings_amount            int64
# seller_rating           float64
# transmission             object
# wheel_system             object
# dtype: object

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['body_type', 'engine_type', 'exterior_color', 'franchise_make',
#        'fuel_type', 'interior_color', 'listing_color', 'make_name',
#        'transmission', 'wheel_system'],
#       dtype='object')

# %%
# List of numerical columns
numerical_columns = ['back_legroom', 'fuel_tank_volume', 'highway_fuel_economy', 'horsepower', 'maximum_seating', 'mileage', 'price', 'savings_amount', 'seller_rating']

# List of categorical columns
categorical_columns = ['body_type', 'engine_type', 'exterior_color', 'fleet', 'franchise_make', 'fuel_type', 'has_accidents', 'interior_color', 'is_new', 'listing_color', 'make_name', 'transmission', 'wheel_system']

# Set the style of the visualization
sns.set(style="whitegrid")

# Create subplots for numerical columns
num_numerical_features = min(3, len(numerical_columns))
fig, axes = plt.subplots(nrows=1, ncols=num_numerical_features, figsize=(5 * num_numerical_features, 5))
fig.suptitle('Numerical Features vs Price', y=1.02)

for i in range(num_numerical_features):
    column = numerical_columns[i]
    sns.scatterplot(x=df[column], y=df['price'], ax=axes[i])
    axes[i].set_title(f'{column} vs Price')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Price')

# Adjust layout
plt.tight_layout()

# Create subplots for categorical columns
num_categorical_features = min(4, len(categorical_columns))
fig, axes = plt.subplots(nrows=1, ncols=num_categorical_features, figsize=(5 * num_categorical_features, 5))
fig.suptitle('Categorical Features vs Price', y=1.02)

for i in range(num_categorical_features):
    column = categorical_columns[i]
    sns.barplot(x=df[column], y=df['price'], ax=axes[i])
    axes[i].set_title(f'{column} vs Price')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Price')
    axes[i].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
# Set the style of the visualization
sns.set(style="whitegrid")

# Create subplots for numerical columns
num_numerical_features = min(3, len(numerical_columns))
fig, axes = plt.subplots(nrows=1, ncols=num_numerical_features, figsize=(5 * num_numerical_features, 5))
fig.suptitle('Numerical Features vs Mileage', y=1.02)

for i in range(num_numerical_features):
    column = numerical_columns[i]
    sns.scatterplot(x=df[column], y=df['mileage'], ax=axes[i])
    axes[i].set_title(f'{column} vs Mileage')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Mileage')

# Adjust layout
plt.tight_layout()

# Create subplots for categorical columns
num_categorical_features = min(4, len(categorical_columns))
fig, axes = plt.subplots(nrows=1, ncols=num_categorical_features, figsize=(5 * num_categorical_features, 5))
fig.suptitle('Categorical Features vs Mileage', y=1.02)

for i in range(num_categorical_features):
    column = categorical_columns[i]
    sns.barplot(x=df[column], y=df['mileage'], ax=axes[i])
    axes[i].set_title(f'{column} vs Mileage')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Mileage')
    axes[i].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()

plt.show()

# %%
cat_cols = ['body_type', 'engine_type', 'exterior_color', 'franchise_make',
            'fuel_type', 'interior_color', 'listing_color', 'make_name',
            'transmission', 'wheel_system']

df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)


df_encoded.select_dtypes(include=['float64']).columns
# Out:
# Index(['back_legroom', 'fuel_tank_volume', 'highway_fuel_economy',
#        'horsepower', 'maximum_seating', 'mileage', 'seller_rating'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

columns_to_scale = ['back_legroom', 'fuel_tank_volume', 'highway_fuel_economy',
                    'horsepower', 'maximum_seating', 'mileage', 'seller_rating']

scaler = StandardScaler()

df_encoded[columns_to_scale] = scaler.fit_transform(df_encoded[columns_to_scale])

# %%
df_encoded.select_dtypes(include=['float64']).head()
# Out:
#    back_legroom  fuel_tank_volume  highway_fuel_economy  horsepower  \
# 0     -0.754660         -1.338471              0.000000   -0.836587
# 1      0.335400         -0.251543              0.000000   -0.044384
# 2     -0.645654         -0.642837             -0.968085    0.633007
# 3      0.153724          1.009293              0.000000    1.034850
# 4      0.335400         -0.251543              0.000000   -0.044384
#
#    maximum_seating   mileage  seller_rating
# 0        -0.398356 -1.051987      -1.374138
# 1         1.252579 -1.051967      -0.985569
# 2        -0.398356  0.000000       0.000000
# 3         1.252579 -1.051905      -0.985569
# 4         1.252579 -1.051987      -0.985569

# %%
mile_df = df_encoded.copy()

X = df_encoded.drop('price', axis=1)
y = df_encoded['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
pred = y_pred.flatten()
act = y_test.values.flatten()

result = pd.DataFrame({'actual':act, 'predicted':pred})


result.head()
# Out:
#    actual     predicted
# 0   29660  24944.752352
# 1   19185  21080.619545
# 2   28345  33497.894573
# 3   14499  19434.313761
# 4   30279  33820.220937

# %%
plt.figure(figsize=(8, 6))
plt.scatter(result['actual'], result['predicted'], alpha=0.5, label='Actual vs Predicted')
plt.plot([result['actual'].min(), result['actual'].max()], [result['actual'].min(), result['actual'].max()], color='red', linestyle='--', linewidth=2, label='Regression Line')

plt.title('Actual vs Predicted Values with Regression Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error,confusion_matrix,mean_absolute_error, mean_squared_error, r2_score

conf_matrix = confusion_matrix(y_test, np.round(y_pred))

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

mae = mean_absolute_error(act, pred)
mse = mean_squared_error(act, pred)
r2 = r2_score(act, pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 4204.8125904699
# Mean Squared Error: 33264178.74370328
# R-squared: 0.8447581831563065

# %%
from sklearn.svm import SVR

SVRegressor = SVR(kernel='rbf',C=1e3, gamma=0.1)
SVRegressor.fit(X_train,y_train)
# Out:
# SVR(C=1000.0, gamma=0.1)

# %%
svr_y_pred = SVRegressor.predict(X_test)

# %%
svr_pred = svr_y_pred.flatten()
svr_act = y_test.values.flatten()

svr_result = pd.DataFrame({'actual':svr_act, 'predicted':svr_pred})


svr_result.head()
# Out:
#    actual     predicted
# 0   29660  30724.446959
# 1   19185  20226.760951
# 2   28345  30043.056311
# 3   14499  20171.772169
# 4   30279  29776.897574

# %%
plt.figure(figsize=(8, 6))
plt.scatter(svr_result['actual'], svr_result['predicted'], alpha=0.5, label='Actual vs Predicted')
plt.plot(svr_result['actual'], svr_y_pred, color='red', linewidth=0.5,linestyle='--', label='SVR Regression Line')

plt.title('Actual vs Predicted Values with Regression Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error,confusion_matrix,mean_absolute_error, mean_squared_error, r2_score

conf_matrix = confusion_matrix(y_test, np.round(svr_y_pred))

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

mae = mean_absolute_error(svr_act, svr_pred)
mse = mean_squared_error(svr_act, svr_pred)
r2 = r2_score(svr_act, svr_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 9012.36767158428
# Mean Squared Error: 151029511.79061934
# R-squared: 0.2951548274183686

# %%
from sklearn.tree import DecisionTreeRegressor

dt_regressor = DecisionTreeRegressor(random_state=0)

dt_regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
dt_y_pred = dt_regressor.predict(X_test)

# %%
dt_pred = dt_y_pred.flatten()
dt_act = y_test.values.flatten()

dt_result = pd.DataFrame({'actual':dt_act, 'predicted':dt_pred})


dt_result.head()
# Out:
#    actual  predicted
# 0   29660    29270.0
# 1   19185    19185.0
# 2   28345    29059.5
# 3   14499    17995.0
# 4   30279    32195.0

# %%
plt.figure(figsize=(8, 6))
plt.scatter(dt_result['actual'], dt_result['predicted'], alpha=0.5, label='Actual vs Predicted')
plt.plot(dt_result['actual'], dt_y_pred, color='red', linewidth=0.5,linestyle='--', label='Decesion Tree Regression Line')

plt.title('Actual vs Predicted Values with Regression Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error,confusion_matrix,mean_absolute_error, mean_squared_error, r2_score

conf_matrix = confusion_matrix(y_test, np.round(dt_y_pred))

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

mae = mean_absolute_error(dt_act, dt_pred)
mse = mean_squared_error(dt_act, dt_pred)
r2 = r2_score(dt_act, dt_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 3493.1975
# Mean Squared Error: 28248923.21625
# R-squared: 0.8681640632778653

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)

rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
rf_y_pred = rf_regressor.predict(X_test)

# %%
rf_pred = rf_y_pred.flatten()
rf_act = y_test.values.flatten()

rf_result = pd.DataFrame({'actual':rf_act, 'predicted':rf_pred})


rf_result.head()
# Out:
#    actual     predicted
# 0   29660  27152.100000
# 1   19185  19298.000000
# 2   28345  27407.885714
# 3   14499  14221.700000
# 4   30279  29672.300000

# %%
plt.figure(figsize=(8, 6))
plt.scatter(rf_result['actual'], rf_result['predicted'], alpha=0.5, label='Actual vs Predicted')
plt.plot(rf_result['actual'], rf_y_pred, color='red', linewidth=0.5,linestyle='--', label='Random Forest Regression Line')

plt.title('Actual vs Predicted Values with Regression Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error,confusion_matrix,mean_absolute_error, mean_squared_error, r2_score

conf_matrix = confusion_matrix(y_test, np.round(rf_y_pred))

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

mae = mean_absolute_error(rf_act, rf_pred)
mse = mean_squared_error(rf_act, rf_pred)
r2 = r2_score(rf_act, rf_pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 3122.006238095238
# Mean Squared Error: 24908508.099462982
# R-squared: 0.8837535692066812

# %%
import matplotlib.pyplot as plt

models = {
    'Linear Regression': LinearRegression(),
    'SVR': SVR(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor()
}

r2_scores = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    r2_scores[name] = r2

plt.bar(r2_scores.keys(), r2_scores.values())
plt.ylabel('R-squared')
plt.title('R-squared Comparison of Regression Models')
plt.ylim(0, 1)  # Adjust the y-axis limit if needed
plt.show()

# %% [markdown]
# ### The Random Forest Regression model has high R-Squared value, which means Random Forest model has the best fit.
# ## Hence, Accuracy of Random Forest Model is high based on R-Squared value.

# %% [markdown]
# # ------------------------------------------------

# %% [markdown]
# # CAR MILEAGE PREDICTION

# %%
XM = mile_df.drop('mileage', axis=1)
ym = mile_df['mileage']

# %%
from sklearn.model_selection import train_test_split

XM_train, XM_test, ym_train, ym_test = train_test_split(XM,ym, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(XM_train, ym_train)
# Out:
# LinearRegression()

# %%
ym_pred = regressor.predict(XM_test)

# %%
pred = ym_pred.flatten()
act = ym_test.values.flatten()

result = pd.DataFrame({'actual':act, 'predicted':pred})


result.head()
# Out:
#      actual  predicted
# 0 -1.051721  -1.249895
# 1 -1.051762  -1.157982
# 2 -1.040496  -0.865456
# 3  0.744939   1.194929
# 4 -1.051639  -0.428402

# %%
plt.figure(figsize=(8, 6))
plt.scatter(result['actual'], result['predicted'], alpha=0.5, label='Actual vs Predicted')
plt.plot([result['actual'].min(), result['actual'].max()], [result['actual'].min(), result['actual'].max()], color='red', linestyle='--', linewidth=2, label='Regression Line')

plt.title('Actual vs Predicted Values with Regression Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(act, pred)
mse = mean_squared_error(act, pred)
r2 = r2_score(act, pred)

print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 0.43171279542455765
# Mean Squared Error: 0.3247450833149676
# R-squared: 0.6481805670077434

# %% [markdown]
# # THE R-Squared value is close to 1.000 which means that we got a good fit for Mileage Prediction.
